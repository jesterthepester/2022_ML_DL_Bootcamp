# %% [markdown]
# # Simple Linear Regression
# **y = a * x + b**

# %%
# Import Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Import Dataset
dataset = pd.read_csv('Salary_Data.csv') ## Change 'Data.csv' to actual data name
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Splitting into Training and Test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %% [markdown]
# ## Training the Simple Linear Regression Set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test Set Results

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# ## Visualising the Training set Results

# %%
plt.scatter(X_train,y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary ($)')
plt.show()

# %% [markdown]
# ## Visualising Test set Results

# %%
plt.scatter(X_test,y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary ($)')
plt.show()

# %% [markdown]
# ## Extra
# How to make a single prediction?<br>How to gain the final equation?

# %%
print(regressor.predict([[12]]))
# Out:
# [138967.5015615]

# %% [markdown]
# 12 is scalar<br>
# [12] is a 1D array<br>
# [[12]] is a 2D array<br>

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [9345.94244312]
# 26816.192244031176

# %% [markdown]
# Therefore, y ($) = 9346 * x + 26816
